# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

os.chdir(r"C:\Users\Chris\Documents\DS Classes and Scripts\DSC530_EDA")
nio = pd.read_csv("NIO.csv")
nio
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2018-09-12   6.000000   6.930000   5.350000   6.600000   6.600000
# 1    2018-09-13   6.620000  12.690000   6.520000  11.600000  11.600000
# 2    2018-09-14  12.660000  13.800000   9.220000   9.900000   9.900000
# 3    2018-09-17   9.610000   9.750000   8.500000   8.500000   8.500000
# 4    2018-09-18   8.730000   9.100000   7.670000   7.680000   7.680000
# ..          ...        ...        ...        ...        ...        ...
# 599  2021-01-29  59.029999  60.709999  56.439999  57.000000  57.000000
# 600  2021-02-01  59.070000  59.119999  54.369999  56.990002  56.990002
# 601  2021-02-02  57.060001  57.540001  54.509998  55.770000  55.770000
# 602  2021-02-03  55.959999  58.720001  54.840000  57.980000  57.980000
# 603  2021-02-04  58.790001  59.200001  57.110001  57.599998  57.599998
#
#         Volume
# 0     66849000
# 1    158346500
# 2    172473600
# 3     56323900
# 4     41827600
# ..         ...
# ...

# %%
nio = nio[:600]
nio
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2018-09-12   6.000000   6.930000   5.350000   6.600000   6.600000
# 1    2018-09-13   6.620000  12.690000   6.520000  11.600000  11.600000
# 2    2018-09-14  12.660000  13.800000   9.220000   9.900000   9.900000
# 3    2018-09-17   9.610000   9.750000   8.500000   8.500000   8.500000
# 4    2018-09-18   8.730000   9.100000   7.670000   7.680000   7.680000
# ..          ...        ...        ...        ...        ...        ...
# 595  2021-01-25  64.050003  64.519997  58.349998  59.990002  59.990002
# 596  2021-01-26  60.040001  60.669998  58.639999  60.310001  60.310001
# 597  2021-01-27  57.950001  59.790001  56.599998  57.150002  57.150002
# 598  2021-01-28  56.759998  59.459999  55.150002  58.369999  58.369999
# 599  2021-01-29  59.029999  60.709999  56.439999  57.000000  57.000000
#
#         Volume
# 0     66849000
# 1    158346500
# 2    172473600
# 3     56323900
# 4     41827600
# ..         ...
# ...

# %%
tesla = pd.read_csv("TSLA.csv")
tesla
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-06-29    3.800000    5.000000    3.508000    4.778000    4.778000
# 1     2010-06-30    5.158000    6.084000    4.660000    4.766000    4.766000
# 2     2010-07-01    5.000000    5.184000    4.054000    4.392000    4.392000
# 3     2010-07-02    4.600000    4.620000    3.742000    3.840000    3.840000
# 4     2010-07-06    4.000000    4.000000    3.166000    3.222000    3.222000
# ...          ...         ...         ...         ...         ...         ...
# 2665  2021-01-29  830.000000  842.409973  780.099976  793.530029  793.530029
# 2666  2021-02-01  814.289978  842.000000  795.559998  839.809998  839.809998
# 2667  2021-02-02  844.679993  880.500000  842.200012  872.789978  872.789978
# 2668  2021-02-03  877.020020  878.080017  853.059998  854.690002  854.690002
# 2669  2021-02-04  855.000000  856.500000  833.419983  849.989990  849.989990
#
#         Volume
# 0     93831500
# ...

# %%
tesla = tesla[:600]
tesla
# Out:
#            Date   Open   High    Low  Close  Adj Close    Volume
# 0    2010-06-29  3.800  5.000  3.508  4.778      4.778  93831500
# 1    2010-06-30  5.158  6.084  4.660  4.766      4.766  85935500
# 2    2010-07-01  5.000  5.184  4.054  4.392      4.392  41094000
# 3    2010-07-02  4.600  4.620  3.742  3.840      3.840  25699000
# 4    2010-07-06  4.000  4.000  3.166  3.222      3.222  34334500
# ..          ...    ...    ...    ...    ...        ...       ...
# 595  2012-11-07  6.200  6.410  6.162  6.308      6.308   8572500
# 596  2012-11-08  6.202  6.376  6.188  6.262      6.262   6370000
# 597  2012-11-09  6.120  6.186  5.970  6.064      6.064   4315000
# 598  2012-11-12  6.058  6.284  6.032  6.214      6.214   2779500
# 599  2012-11-13  6.258  6.400  6.144  6.322      6.322   4991500
#
# [600 rows x 7 columns]

# %%
df = pd.concat([nio, tesla],axis=1)
df
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2018-09-12   6.000000   6.930000   5.350000   6.600000   6.600000
# 1    2018-09-13   6.620000  12.690000   6.520000  11.600000  11.600000
# 2    2018-09-14  12.660000  13.800000   9.220000   9.900000   9.900000
# 3    2018-09-17   9.610000   9.750000   8.500000   8.500000   8.500000
# 4    2018-09-18   8.730000   9.100000   7.670000   7.680000   7.680000
# ..          ...        ...        ...        ...        ...        ...
# 595  2021-01-25  64.050003  64.519997  58.349998  59.990002  59.990002
# 596  2021-01-26  60.040001  60.669998  58.639999  60.310001  60.310001
# 597  2021-01-27  57.950001  59.790001  56.599998  57.150002  57.150002
# 598  2021-01-28  56.759998  59.459999  55.150002  58.369999  58.369999
# 599  2021-01-29  59.029999  60.709999  56.439999  57.000000  57.000000
#
#         Volume        Date   Open   High    Low  Close  Adj Close    Volume
# ...

# %%
df.columns = ['Index', 'Nio Open', 'Nio High', 'Nio Low', 'Nio Close', 'NioAdjCl', 'Nio Vol', 'Date', 'Tesla Open',
             'Tesla High', 'Tesla Low', 'Tesla Close', 'TAdjCl', 'Tesla Vol']
df
# Out:
#           Index   Nio Open   Nio High    Nio Low  Nio Close   NioAdjCl  \
# 0    2018-09-12   6.000000   6.930000   5.350000   6.600000   6.600000
# 1    2018-09-13   6.620000  12.690000   6.520000  11.600000  11.600000
# 2    2018-09-14  12.660000  13.800000   9.220000   9.900000   9.900000
# 3    2018-09-17   9.610000   9.750000   8.500000   8.500000   8.500000
# 4    2018-09-18   8.730000   9.100000   7.670000   7.680000   7.680000
# ..          ...        ...        ...        ...        ...        ...
# 595  2021-01-25  64.050003  64.519997  58.349998  59.990002  59.990002
# 596  2021-01-26  60.040001  60.669998  58.639999  60.310001  60.310001
# 597  2021-01-27  57.950001  59.790001  56.599998  57.150002  57.150002
# 598  2021-01-28  56.759998  59.459999  55.150002  58.369999  58.369999
# 599  2021-01-29  59.029999  60.709999  56.439999  57.000000  57.000000
#
#        Nio Vol        Date  Tesla Open  Tesla High  Tesla Low  Tesla Close  \
# ...

# %%
# Import library and dataset
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import norm
#df = sns.load_dataset('')
 
# Method 1: on the same Axis
sns.distplot(df["Nio High"], color="skyblue", label="Nio High", fit=norm)
sns.distplot(df["Tesla High"], color="red", label="Tesla High", fit=norm)
plt.legend()
plt.xlabel("Daily High Price")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
# library and data
import seaborn as sns
import matplotlib.pyplot as plt
#df = sns.load_dataset('iris')
 
# plot
sns.distplot( df["Nio Low"] , color="skyblue", label="Nio Low", fit=norm)
sns.distplot( df["Tesla Low"] , color="red", label="Tesla Low", fit=norm)
plt.legend()
plt.xlabel("Daily Low Price")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
# plot

sns.distplot( df["Nio Open"] , color="skyblue", label="Nio Open", fit=norm)
sns.distplot( df["Tesla Open"] , color="red", label="Tesla Open", fit=norm)
plt.legend()
plt.xlabel("Daily Opening Price")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
sns.distplot( df["Nio Close"] , color="skyblue", label="Nio Close", fit=norm)
sns.distplot( df["Tesla Close"] , color="red", label="Tesla Close", fit=norm)
plt.legend()
plt.xlabel("Daily Closing Price")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
sns.distplot( df["Nio Vol"] , color="skyblue", label="Nio Vol", fit=norm)
sns.distplot( df["Tesla Vol"] , color="red", label="Tesla Vol", fit=norm)
plt.legend()
plt.xlabel("Daily Volume of Shares Traded")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
 df.describe()
# Out:
#          Nio Open    Nio High     Nio Low   Nio Close    NioAdjCl  \
# count  600.000000  600.000000  600.000000  600.000000  600.000000
# mean    11.025883   11.454017   10.569650   11.046317   11.046317
# std     14.195104   14.716248   13.592902   14.217751   14.217751
# min      1.190000    1.450000    1.190000    1.320000    1.320000
# 25%      3.147500    3.270000    3.065000    3.187500    3.187500
# 50%      5.490000    5.655000    5.290000    5.375000    5.375000
# 75%      9.805000   10.280000    9.167500    9.805000    9.805000
# max     64.949997   66.989998   62.189999   62.700001   62.700001
#
#             Nio Vol  Tesla Open  Tesla High   Tesla Low  Tesla Close  \
# count  6.000000e+02  600.000000  600.000000  600.000000    600.00000
# mean   6.724582e+07    5.511090    5.631053    5.375430      5.50272
# std    7.773448e+07    0.877389    0.893058    0.870346      0.88620
# min    5.111000e+06    3.228000    3.326000    2.996000      3.16000
# ...

# %%
df["Nio Open"].mode()
# Out:
# 0    3.0
# dtype: float64

# %%
df["Nio Close"].mode()
# Out:
# 0    2.6
# dtype: float64

# %%
df["Nio High"].mode()
# Out:
# 0    3.33
# dtype: float64

# %%
df["Nio Low"].mode()
# Out:
# 0    3.0
# dtype: float64

# %%
df["Nio Vol"].mode()
# Out:
# 0        5111000
# 1        5686000
# 2        5920000
# 3        6379600
# 4        6723600
#          ...
# 595    385210600
# 596    432720700
# 597    444070500
# 598    570911400
# 599    577185100
# Length: 600, dtype: int64

# %%
df["Tesla Open"].mode()
# Out:
# 0    5.6
# 1    6.0
# dtype: float64

# %%
df["Tesla Close"].mode()
# Out:
# 0    5.484
# dtype: float64

# %%
df["Tesla High"].mode()
# Out:
# 0    5.6
# 1    6.0
# dtype: float64

# %%
df["Tesla Low"].mode()
# Out:
# 0    5.46
# 1    5.60
# dtype: float64

# %%
df["Tesla Vol"].mode()
# Out:
# 0    3372500
# 1    3645000
# 2    3646500
# 3    4768500
# 4    4782000
# 5    4931500
# 6    4938000
# 7    4998500
# 8    5169500
# 9    5800500
# dtype: int64

# %%
nio_high_spread = (df["Nio High"].max() - df["Nio High"].min())
nio_high_spread
# Out:
# 65.539998

# %%
nio_low_spread = (df["Nio Low"].max() - df["Nio Low"].min())
nio_low_spread
# Out:
# 60.999999

# %%
nio_open_spread = (df["Nio Open"].max() - df["Nio Open"].min())
nio_open_spread
# Out:
# 63.759997

# %%
nio_close_spread = (df["Nio Close"].max() - df["Nio Close"].min())
nio_close_spread
# Out:
# 61.380001

# %%
nio_vol_spread = (df["Nio Vol"].max() - df["Nio Vol"].min())
nio_vol_spread
# Out:
# 572074100

# %%
tesla_high_spread = (df["Tesla High"].max() - df["Tesla High"].min())
tesla_high_spread
# Out:
# 4.664

# %%
tesla_low_spread = (df["Tesla Low"].max() - df["Tesla Low"].min())
tesla_low_spread
# Out:
# 4.426

# %%
tesla_open_spread = (df["Tesla Open"].max() - df["Tesla Open"].min())
tesla_open_spread
# Out:
# 4.41

# %%
tesla_close_spread = (df["Tesla Close"].max() - df["Tesla Close"].min())
tesla_close_spread
# Out:
# 4.442

# %%
tesla_vol_spread = (df["Tesla Vol"].max() - df["Tesla Vol"].min())
tesla_vol_spread

# %%
# PMF
# Out:
# 93239000

# %%
import yfinance as yf

nio = yf.Ticker("NIO")

# get stock info
nio.info

# get historical market data
hist = nio.history(period="max")

# %%
nio.info
# Out:
# {'zip': '201804',
#  'sector': 'Consumer Cyclical',
#  'fullTimeEmployees': 7442,
# ...

# %%
nio.major_holders
# Out:
#         0                                      1
# 0   0.56%        % of Shares Held by All Insider
# 1  36.33%       % of Shares Held by Institutions
# 2  36.54%        % of Float Held by Institutions
# 3     564  Number of Institutions Holding Shares

# %%
nio.institutional_holders
# Out:
#                                           Holder     Shares Date Reported  \
# 0                    Baillie Gifford and Company  107907768    2020-12-30
# 1                                 Blackrock Inc.   61499542    2020-12-30
# 2                     Vanguard Group, Inc. (The)   39688284    2020-12-30
# 3                       State Street Corporation   27123122    2020-12-30
# 4                          Shaw D.E. & Co., Inc.   15415735    2020-12-30
# 5                      Goldman Sachs Group, Inc.   10858121    2020-12-30
# 6                              Credit Suisse Ag/   10242313    2020-12-30
# 7  Healthcare of Ontario Pension Plan Trust Fund    8500000    2020-12-30
# 8                      Legal & General Group PLC    7995333    2020-12-30
# 9                         Jane Street Group, LLC    6847284    2020-12-30
#
#     % Out       Value
# 0  0.0835  5259424612
# 1  0.0476  2997487677
# 2  0.0307  1934406962
# 3  0.0210  1321980966
# 4  0.0119   751362923
# ...

# %%
import matplotlib.pylab as plt
# Generating a stock scatter plot, use nio high for x and tesla high for y to start

sns.regplot(x=df['Nio Vol'], y=df['Tesla Vol'])
plt.legend(loc='upper right')
# Out:
# C:\Users\Chris\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# No handles with labels found to put in legend.

# %%
# The 2nd scatter plot this time start looking at the io low for x and tesla low for y

sns.regplot(x=df['Nio High'], y=df['Tesla High'])
